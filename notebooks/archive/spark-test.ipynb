# %% [markdown]
# # Test Notebook
# This is just an (almost) empty test notebook.
# You can run the following code to assert that Spark is installed and working within the container.

# %%
from pyspark import SparkContext, SparkConf

conf = SparkConf().setMaster("local").setAppName("Spark Test")
sc = SparkContext(conf=conf)
